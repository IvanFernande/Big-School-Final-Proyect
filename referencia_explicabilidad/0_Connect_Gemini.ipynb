# %% [markdown]
# https://ai.google.dev/gemini-api/docs/quickstart?hl=es-419&lang=python

# %%
api_key = 'AIzaSyAwt3rC4QKV-ZvG1EGOW3jUFekFntuHcxU'

# %%
import google.generativeai as genai

from IPython.display import display, Markdown

# %%
genai.configure(api_key=api_key)

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
response = model.generate_content("Explain how AI works")

# %%
display(Markdown(response.text))
# Out:
# AI works by combining large amounts of data with fast, iterative processing and intelligent algorithms, allowing the software to learn automatically from patterns or features in the data.  There's no single "how it works" because AI encompasses many different techniques, but here's a breakdown of some core principles:
#
# **1. Data Acquisition and Preparation:**
#
# * **Data Collection:** AI systems require massive datasets relevant to the task they're designed for. This could be images for image recognition, text for natural language processing, or sensor readings for robotics.
# * **Data Cleaning:** Real-world data is messy. This stage involves removing inconsistencies, handling missing values, and transforming data into a format suitable for the algorithms.
# * **Data Preprocessing:** This involves scaling, normalizing, and transforming the data to improve the performance of the algorithms.  Techniques like feature engineering (selecting or creating relevant data features) are crucial here.
#
# **2. Algorithms and Models:**
#
# This is the heart of AI, where the "learning" happens.  Different AI approaches use different algorithms:
#
# * **Machine Learning (ML):**  This is a broad category where algorithms learn from data without explicit programming.  Key subfields include:
#     * **Supervised Learning:**  The algorithm learns from labeled data (e.g., images labeled as "cat" or "dog").  Examples include classification (assigning data points to categories) and regression (predicting a continuous value).
#     * **Unsupervised Learning:** The algorithm learns from unlabeled data, identifying patterns and structures.  Examples include clustering (grouping similar data points) and dimensionality reduction (reducing the number of variables).
#     * **Reinforcement Learning:**  The algorithm learns through trial and error, receiving rewards or penalties for its actions.  This is commonly used in robotics and game playing.
#
# * **Deep Learning (DL):**  A subset of ML that uses artificial neural networks with multiple layers (hence "deep").  These networks can learn complex patterns from vast amounts of data, excelling in tasks like image recognition, natural language processing, and speech recognition.
#
# * **Other Approaches:**  AI also includes expert systems (rule-based systems), evolutionary algorithms (inspired by natural selection), and symbolic AI (using logic and reasoning).
#
#
# **3. Training the Model:**
#
# This is where the algorithm learns from the prepared data.  The process typically involves:
#
# * **Feeding the data:** The algorithm processes the data, adjusting its internal parameters to minimize errors and improve its performance on the task.
# * **Optimization:**  Algorithms use optimization techniques (like gradient descent) to find the best set of parameters that minimize the error.
# * **Evaluation:** The model's performance is evaluated on a separate dataset (the test set) to assess its generalization ability (how well it performs on unseen data).
#
# **4. Deployment and Monitoring:**
#
# Once trained, the model can be deployed to perform its intended task.  This might involve integrating it into a software application, a robot, or a cloud service.  Continuous monitoring is essential to track performance and make adjustments as needed.
#
#
# **In simple terms:**  Imagine teaching a dog a trick. You show it examples (data), reward it when it gets it right (optimization), and correct it when it's wrong (error correction).  Over time, the dog learns the trick (the model learns).  AI works similarly, but at a much larger scale and with much more complex algorithms.  The key is learning from data and improving performance over time.
